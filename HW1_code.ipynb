# %% [markdown]
# <a href="https://colab.research.google.com/github/Raggant5/Lab-1/blob/main/HW1_code.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# First import the necessary libraries

# %%
import numpy as np

# %% [markdown]
# Define the basis vectors

# %%
e1 = np.array([1, 0], dtype=np.float64)  # the first basis vector (EDIT THIS)
e2 = np.array([0, 1], dtype=np.float64)  # the second basis vector (EDIT THIS)

# %% [markdown]
# Define the coefficients you previously computed in HW1 Q5.

# %%
a1 = 1  # EDIT THIS
a2 = 1  # EDIT THIS

# %% [markdown]
# Compute the vector x = [1, 1].

# %%
x = a1 * e1 + a2 * e2
print("x = ")
print(x)
